# %%
import pandas as pd

# %%
file=r"C:\Users\ASUS\titanic_train.csv"  # Path of file

# %%
df=pd.read_csv(file)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  98.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(file)  # syntax for reading the file

# Assuming you have the data in a DataFrame named 'df'
# Replace 'ratings_column' and 'cost_column' with the actual column names in your DataFrame

# Sample DataFrame creation for illustration (Replace this with your actual data loading step)
# df = pd.read_csv('your_data_file.csv')

# Creating distplots for the two columns
plt.figure(figsize=(12, 6))

# Distribution of Ratings
plt.subplot(1, 2, 1)
sns.histplot(df['Fare'].dropna(), kde=True, bins=30)
plt.title("Fare price")
plt.xlabel('Price')
plt.ylabel('Frequency')



plt.tight_layout()
plt.show()

# %%
sns.distplot(df['Pclass'])
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_22352\2994265646.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Pclass'])

# %%
sns.boxplot(df['Pclass'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and 'Pclass' is a column in it
sns.histplot(df['Survived'], kde=True, stat="density", common_norm=False, bins=30, color='blue', element='step', fill=False)

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and 'Pclass' is a column in it
sns.histplot(df['Survived'], kde=True, stat="density", common_norm=False, bins=30, fill=False)

# Show the plot
plt.show()
